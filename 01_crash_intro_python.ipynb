# %%
print("Welcome to the Data Science in Techno-Socio-Economic Systems class 2020, lecturer Nino Antulov-Fantulin")

msg = """If you know the enemy and know yourself, you need not fear the result of a hundred battles. 
If you know yourself but not the enemy,  for every victory gained you will also suffer a defeat. 
If you know neither  the enemy nor yourself, you will succumb in every battle. -- Sun Tzu, The Art of War """

print(msg)

# %%
# whitespacing  -- identation for blocks
# !NOTE, that tabs and whitespaces are not the same. 
# Recommendation: use 4 spaces!

war_toolbox = [ "Python", "Conda", "Git", "Cython"]
comment_list = [ "is cool !", "simplifies dependecies" , "allows versioning!", "is python with speed of C/C++"]

offset = 0
for x in war_toolbox:
    print("--"+x)
    for j in range(0,len(comment_list)):
        if (j==offset):
            print(comment_list[j])
    offset +=1
print("Check them!")

#whitespaces are ignored inside parenthis and brackets

links_toolbox = [ "Python tutorial will follow the book https://github.com/ab-anand/py-books/blob/master/Data%20Science%20from%20Scratch-%20First%20Principles%20with%20Python.pdf",
               "Conda: https://docs.conda.io/en/latest/", 
               "Git: https://www.atlassian.com/git/tutorials/what-is-git", 
               "Cython: https://cython.org"]

#pythonic way ...
type([print(x) for x in links_toolbox])

# 1st lecture will follow the book
# Credit: Joel Grus
# Data Science from Scratch- First Principles with Python, 
# https://github.com/joelgrus/data-science-from-scratch

# %%
# modules
import re as regex #import whole module
my_regex = regex.compile("[0-9]+", regex.I)

print(my_regex.match("94343"))
print(my_regex.match("9434ff3"))

from collections import defaultdict, Counter
lookup = defaultdict(int)
my_counter = Counter()

match = 10
print(match)
from re import *    # Do not do this!
print(match)        # "<function match at 0x10281e6a8>"

# %%
#artithemtics
print(5//2)
print(5/2)

# functions
def double(x):
    """
    This is where you put an optional docstring that explains what the
    function does. For example, this function multiplies its input by 2.
    """
    return x * 2

def apply_to_one(f):
    """Calls the function f with 1 as its argument"""
    return f(1)

my_double = double             # refers to the previously defined function
x = apply_to_one(my_double)    # equals 2

print(x)

#Python's assert statement is a debugging aid that tests a condition. 
# If the condition is true, it does nothing and your program just continues to execute. 
# But if the assert condition evaluates to false, it raises an AssertionError exception with an optional error message.
assert x == 2


# anonymous function
y = apply_to_one(lambda x: x + 4)      # equals 5

assert y == 5

another_double = lambda x: 2 * x       # Don't do this

def another_double(x):
    """Do this instead"""
    return 2 * x

# default values
def my_print(message = "my default message"):
    print(message)

my_print("hello")   # prints 'hello'
my_print()          # prints 'my default message'


def full_name(first = "What's-his-name", last = "Something"):
    return first + " " + last

full_name("Joel", "Grus")     # "Joel Grus"
full_name("Joel")             # "Joel Something"
full_name(last="Grus")        # "What's-his-name Grus"


assert full_name("Joel", "Grus")     == "Joel Grus"
assert full_name("Joel")             == "Joel Something"
assert full_name(last="Grus")        == "What's-his-name Grus"

# %%
#exceptions
import sys
try:
    y = 2 / 0
except ZeroDivisionError:
    print(sys.exc_info())

# %%
# data structures
my_list = [1, 2, 3, 4]
my_tuple = (1, 2)
other_tuple = 3, 4
my_list[1] = 3  

try:
    my_tuple[1] = 3
except TypeError:
    print("cannot modify a tuple")
    
# The value of some objects can change. 
# Objects whose value can change are said to be mutable; 
# objects whose value is unchangeable once they are created are called immutable.
# Objects of built-in types like (int, float, bool, str, tuple, unicode) are immutable. 
# Objects of built-in types like (list, set, dict) are mutable. Custom classes are generally mutable

# DIY
list_values = [1, 2, 3]
print(id(list_values))
list_values += [4, 5, 6]
print(id(list_values))
print()


tupple_values = (1, 2, 3)
print(id(tupple_values))
tupple_values += (4, 5, 6)
print(id(tupple_values))
print()

number = 42
print(id(number))

number += 1
print(id(number))
print("-----------------")

# %%
# Copying Mutable Objects by Reference
values = [4, 5, 6]
values2 = values
print(id(values))
print(id(values2))

values.append(7)
print(values is values2)
print(values)
print(values2)
print()

# Copying Immutable Objects
text = "Python"
text2 = text
print(id(text))
print(id(text2))
print(text is text2)
print()

text += " is cool"
print(id(text))
print(id(text2))
print(text is text2)
print()

print(text)
print(text2)

# %%
numbers = [1, 2, 3]
numbers2 = [1, 2, 3]
print(numbers == numbers2) # comparison by value
print(numbers is numbers2) # comparison bt reference

# The value of an immutable container (e.g. tupple) that contains a reference to a mutable object can be changed if that mutable object is changed. 
# check https://towardsdatascience.com/https-towardsdatascience-com-python-basics-mutable-vs-immutable-objects-829a0cb1530a

print()
skills = ["Programming", "Machine Learning", "Statistics"]
person = (129392130, skills) # tupple is not mutable
print(type(person))
print(person)

skills[2] = "Maths" # changing mutable container list
print(person)

# %%
#dictionary

empty_dict = {}                     # Pythonic
grades = {"Joel": 80, "Tim": 95}    # dictionary literal

joels_grade = grades["Joel"]        # equals 80


assert joels_grade == 80

try:
    kates_grade = grades["Kate"]
except KeyError:
    print("no grade for Kate!")

print("Joel" in grades)     # True
print("Kate" in grades)     # False

joels_grade = grades.get("Joel", 0)   # equals 80
kates_grade = grades.get("Kate", 0)   # equals 0
no_ones_grade = grades.get("No One")  # default default is None


assert joels_grade == 80
assert kates_grade == 0
assert no_ones_grade is None

grades["Tim"] = 99                    # replaces the old value
grades["Kate"] = 100                  # adds a third entry
num_students = len(grades)            # equals 3
print(num_students)

document = ["data", "science", "from", "scratch", "data", "data"]

word_counts = {}
for word in document:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1
        
print(word_counts)

# %%
# sets
s = set()
s.add(1)       # s is now {1}
s.add(2)       # s is now {1, 2}
s.add(2)       # s is still {1, 2}
x = len(s)     # equals 2
y = 2 in s     # equals True
z = 3 in s     # equals False
print(x,y,z)

item_list = [1, 2, 3, 1, 2, 3]
item_set = set(item_list)                 # {1, 2, 3}
print(item_set)

# %%
#sorting
x = [4, 1, 2, 3]
y = sorted(x)     # y is [1, 2, 3, 4], x is unchanged
print(y)
x.sort()          # now x is [1, 2, 3, 4]
print(x)

# sort the list by absolute value from largest to smallest
x = sorted([-4, 1, -2, 3], key=abs, reverse=True)  # is [-4, 3, -2, 1]
print(x)

# %%
#list comprehensions -- easy manipulation on lists
even_numbers = [x for x in range(5) if x % 2 == 0]  # [0, 2, 4]
squares      = [x * x for x in range(5)]            # [0, 1, 4, 9, 16]
even_squares = [x ** 2 for x in even_numbers]        # [0, 4, 16]
print(even_numbers)
print(squares)
print(even_squares)


square_dict = {x: x * x for x in range(5)}  # {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}
print(square_dict)
square_set  = {x * x for x in range(5)}      
print(square_set)

# %%
# generators -- lazy iteration over list
def natural_numbers():
    """returns 1, 2, 3, ..."""
    n = 1
    while True:
        yield n
        n += 1
        
# The yield statement suspends function’s execution and sends a value back to the caller, 
# but retains enough state to enable function to resume where it is left off. 
# When resumed, the function continues execution immediately after the last yield run. 
# This allows its code to produce a series of values over time, rather than computing them at once and 
# sending them back like a list.

for x in natural_numbers(): #generator
    if x>10:
        break;
    else:
        print(x)
        
print("----")

data = natural_numbers()
evens = (x for x in data if x % 2 == 0)
even_squares = (x ** 2 for x in evens)
even_squares_ending_in_six = (x for x in even_squares if x % 10 == 6)


for x in even_squares_ending_in_six:
    if x<1000:
        print(x);
    else:
        break;
        
print("----")

evens2 = (x for x in natural_numbers() if x % 2 == 0)
for x in evens2:
    if x<10:
        print(x);
    else:
        break;

# %%
names = ["Alice", "Bob", "Charlie", "Debbie"]


# Pythonic -- Enumerate() method adds a counter to an iterable and returns it in a form of enumerate object. 
for i, name in enumerate(names):
    print(f"name {i} is {name}")
    
# iterator
iter_obj=iter([3,4,5])
print(next(iter_obj))
print(next(iter_obj))
print()

# iterator
iter_obj=iter(natural_numbers())
print(next(iter_obj))
print(next(iter_obj))
print(next(iter_obj))
print(next(iter_obj))

# %%
# object oriented programming

class CountingClicker:
    """A class can/should have a docstring, just like a function"""

    def __init__(self, count = 0):
        self.count = count

    def __repr__(self):
        return f"CountingClicker(count={self.count})"

    def click(self, num_times = 1):
        """Click the clicker some number of times."""
        self.count += num_times

    def read(self):
        return self.count

    def reset(self):
        self.count = 0

# %%
clicker = CountingClicker()
assert clicker.read() == 0, "clicker should start with count 0"
clicker.click()
clicker.click()
assert clicker.read() == 2 # "after two clicks, clicker should have count 2"
clicker.reset()
assert clicker.read() == 0

# %%
 #A subclass inherits all the behavior of its parent class.
class NoResetClicker(CountingClicker):
    # This class has all the same methods as CountingClicker

    # Except that it has a reset method that does nothing.
    def reset(self):
        pass

clicker2 = NoResetClicker()
assert clicker2.read() == 0
clicker2.click()
assert clicker2.read() == 1
clicker2.reset()
assert clicker2.read() == 1
